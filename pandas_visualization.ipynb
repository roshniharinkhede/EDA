# %% [markdown]
# <a href="https://colab.research.google.com/github/roshniharinkhede/EDA/blob/main/pandas_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.rand(1000,1) , index=pd.date_range('2022-11-27' , periods=1000) , columns=['data'])

# %%
df
# Out:
#                 data
# 2022-11-27  0.588131
# 2022-11-28  0.897714
# 2022-11-29  0.891531
# 2022-11-30  0.815837
# 2022-12-01  0.035890
# ...              ...
# 2025-08-18  0.992189
# 2025-08-19  0.756037
# 2025-08-20  0.299186
# 2025-08-21  0.261712
# 2025-08-22  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()

# %%
df.data.cumsum()
# Out:
# 2022-11-27      0.588131
# 2022-11-28      1.485845
# 2022-11-29      2.377375
# 2022-11-30      3.193213
# 2022-12-01      3.229102
#                  ...
# 2025-08-18    495.812936
# 2025-08-19    496.568973
# 2025-08-20    496.868159
# 2025-08-21    497.129872
# 2025-08-22    498.098851
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
df.data.cumsum().plot()

# %%
df['data1']=df.data.cumsum()

# %%
df['data2']=df.data.apply(lambda x :(x*3))

# %%
df
# Out:
#                 data       data1     data2
# 2022-11-27  0.588131    0.588131  1.764392
# 2022-11-28  0.897714    1.485845  2.693141
# 2022-11-29  0.891531    2.377375  2.674592
# 2022-11-30  0.815837    3.193213  2.447512
# 2022-12-01  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2025-08-18  0.992189  495.812936  2.976566
# 2025-08-19  0.756037  496.568973  2.268112
# 2025-08-20  0.299186  496.868159  0.897559
# 2025-08-21  0.261712  497.129872  0.785137
# 2025-08-22  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
df.plot()

# %%
df.plot(figsize =(10,10))

# %%
from plotly.

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.plot(figsize=(10,10),title="irish data")

# %%
gf=df1.plot(figsize=(10,10),title="irish data")
gf.set_xlabel("this is x axis")
gf.set_ylabel("this is y axis")
# Out:
# Text(0, 0.5, 'this is y axis')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df1.iloc[0][0:4].plot()

# %%
df1.iloc[0][0:4].plot(kind='bar')

# %%
df2 = sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
df2['pclass'].plot(kind = 'bar')

# %%
df3=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
df3.plot.bar()

# %%
df3.plot.barh()

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1['petal_length'].plot.hist()

# %%
df1.plot(kind = 'hist',stacked=True, bins = 100, figsize=(10,10),title="histogram of irish")

# %%
df1.plot(kind = 'hist',stacked=True, bins = 100, figsize=(10,10),title="histogram of irish",orientation='horizontal')

# %%
df1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1b17d1e450>,
# ...
#       dtype=object)

# %%
df1.hist(figsize=(10,10),color='r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1b179b2b90>,
# ...
#       dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.scatter(x = 'sepal_width',y = 'petal_width')

# %%
df1.plot.scatter(x = 'sepal_length',y = 'petal_width', c = 'petal_length')

# %%
df1.plot.hexbin(x = 'sepal_length',y = 'petal_width', label='Roshni',gridsize=10)

# %%
df
# Out:
#                 data       data1     data2
# 2022-11-27  0.588131    0.588131  1.764392
# 2022-11-28  0.897714    1.485845  2.693141
# 2022-11-29  0.891531    2.377375  2.674592
# 2022-11-30  0.815837    3.193213  2.447512
# 2022-12-01  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2025-08-18  0.992189  495.812936  2.976566
# 2025-08-19  0.756037  496.568973  2.268112
# 2025-08-20  0.299186  496.868159  0.897559
# 2025-08-21  0.261712  497.129872  0.785137
# 2025-08-22  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]

# %%
d
# Out:
# data     0.588131
# data1    0.588131
# data2    1.764392
# Name: 2022-11-27 00:00:00, dtype: float64

# %%
d.plot.pie(figsize=(10,10))

# %%
df1.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
irish=df1.head(3).T

# %%
irish.iloc[0:4]
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
irish.iloc[0:4].plot.pie(subplots=True,figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f1b1449d590>,
# ...
#       dtype=object)

# %%
irish.iloc[0:4].plot.pie(subplots=True,figsize=(20,20),fontsize=10, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f1b1435bb10>,
# ...
#       dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.scatter_matrix(df1,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1b139501d0>,
# ...
#       dtype=object)

# %%
from numpy.core.fromnumeric import diagonal
pd.plotting.scatter_matrix(df1,figsize=(10,10),diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1b136b7bd0>,
# ...
#       dtype=object)

# %%
df
# Out:
#                 data       data1     data2
# 2022-11-27  0.588131    0.588131  1.764392
# 2022-11-28  0.897714    1.485845  2.693141
# 2022-11-29  0.891531    2.377375  2.674592
# 2022-11-30  0.815837    3.193213  2.447512
# 2022-12-01  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2025-08-18  0.992189  495.812936  2.976566
# 2025-08-19  0.756037  496.568973  2.268112
# 2025-08-20  0.299186  496.868159  0.897559
# 2025-08-21  0.261712  497.129872  0.785137
# 2025-08-22  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
df['data'].plot(style = 'r--')

# %%
df['data'].plot(style = 'r--', legend = True , label = 'Roshni')

# %%
df['data'].plot(style = 'r*', legend = True , label = 'Roshni')
